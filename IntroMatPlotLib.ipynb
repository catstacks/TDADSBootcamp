# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
y = np.linspace(-1, 1, 5)
y2 = np.linspace(-3, 3, 5)
x = np.arange(5)

# %%
fig = plt.figure()
ax = fig.subplots()
line1= ax.plot(x,y)
line2 = ax.plot(x,y2)

# %%
fig2 = plt.figure()
ax2 = fig2.subplots(3, 2)
plt.tight_layout()
ax2[2,1].plot(x,y) 
ax2[0,0].plot(x,y2)

# %%
fig3 = plt.figure()
y1 = np.arange(0,110.10)
y2 = np.random.random(11)
x = np.arange(11)

fig3, ax = plt.subplots(2,2)
ax[0,0].plot(x,y1)
ax[0,1].scatter(x,y2)
ax[1,0].bar(x,y1)
ax[1,1].barh(x,y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15564/733600655.py in <module>
#       5
#       6 fig3, ax = plt.subplots(2,2)
# ----> 7 ax[0,0].plot(x,y1)
#       8 ax[0,1].scatter(x,y2)
#       9 ax[1,0].bar(x,y1)
#
# C:\Python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# C:\Python39\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# C:\Python39\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (11,) and (111,)
